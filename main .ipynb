# %%
from cadastro import cadastro_curso, cadastro_aluno, adicionar_notas

# etapa 1: cadastrar cursos e guardar na variável 'meus_cursos'
meus_cursos = cadastro_curso()

# etapa 2: cadastrar alunos passando a lista de cursos disponíveis
meus_alunos = cadastro_aluno(meus_cursos)

# etapa 3: adicionar notas para a lista de alunos cadastrados
adicionar_notas(meus_alunos)

# etapa 4: mostrar dados
for aluno in meus_alunos:
    aluno.mostrar_dados()
# Out:
# Cadastro do curso 1:
#
# Cadastro do aluno 1:
# 1 - matematica
#
# --- Adicionando 2 notas para: joaquim ---
# Nome : joaquim
# Matricula : 12345678
# Média : 7.5
# Curso de matematica, duração de 6 semestres.
